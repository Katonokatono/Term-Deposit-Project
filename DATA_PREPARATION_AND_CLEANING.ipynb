# %% [markdown]
# <a href="https://colab.research.google.com/github/Katonokatono/Term-Deposit-Project/blob/Data-Cleaning/DATA_PREPARATION_AND_CLEANING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Describing the Question
#
# A term deposit is a fixed-term investment that includes the deposit of money into an account at a financial institution. Term deposit investments usually carry short-term maturities ranging from one month to a few years and will have varying levels of required minimum deposits. Typically, term deposits offer higher interest rates than traditional liquid savings accounts, whereby customers can withdraw their money at any time, but there’s a catch, upon withdrawal of the money before the set maturity date, most institutions fail to pay the interest rates. Term deposits are a lucrative investment to banks whereby the money invested by customers can be used to invest in projects that can give profits, provide liquidity to provide loans to other customers.

# %% [markdown]
# ##Specifying the Question
#
# Our research seeks to provide insights of the best-optimised solution for the bank to gain more customers to invest in the bank term deposits by analysing the patterns and trends of the bank's existing customer pool.

# %% [markdown]
# ##Defining the metric of success
#
# To identify existing customers who are relatively more likely to subscribe to term deposit.
#
# To identify which demographic factors influence a customer to subscribe to the bank term deposit investments.

# %% [markdown]
# ##Experimental Design
#
# Exploratory Data Analysis
#
# Data Cleaning
#
# Univariate, Bivariate Analysis
#
# Visualizations
#
# Testing a Hypothesis
#
# Challenge our solution by providing insights on how we can make improvements.

# %% [markdown]
# ##Data Preparation

# %%
#importing libraries
# importing pandas
import pandas as pd

# importing numpy
import numpy as np

# importing matplotlib.pyplot
import matplotlib.pyplot as plt

# importing scipy.stats
import scipy.stats as stats

# importing seaborn
import seaborn as sns

# %%
#loading dataset
bank=pd.read_csv("/content/bank-additional-full.csv",delimiter=";")
bank
# Out:
#        age          job  marital  ... euribor3m nr.employed    y
# 0       56    housemaid  married  ...     4.857      5191.0   no
# 1       57     services  married  ...     4.857      5191.0   no
# 2       37     services  married  ...     4.857      5191.0   no
# 3       40       admin.  married  ...     4.857      5191.0   no
# 4       56     services  married  ...     4.857      5191.0   no
# ...    ...          ...      ...  ...       ...         ...  ...
# 41183   73      retired  married  ...     1.028      4963.6  yes
# 41184   46  blue-collar  married  ...     1.028      4963.6   no
# 41185   56      retired  married  ...     1.028      4963.6   no
# 41186   44   technician  married  ...     1.028      4963.6  yes
# 41187   74      retired  married  ...     1.028      4963.6   no
#
# [41188 rows x 21 columns]

# %%
#Checking the head
bank.head()
# Out:
#    age        job  marital  ... euribor3m nr.employed   y
# 0   56  housemaid  married  ...     4.857      5191.0  no
# 1   57   services  married  ...     4.857      5191.0  no
# 2   37   services  married  ...     4.857      5191.0  no
# 3   40     admin.  married  ...     4.857      5191.0  no
# 4   56   services  married  ...     4.857      5191.0  no
#
# [5 rows x 21 columns]

# %%
#Checking the tail
bank.tail()
# Out:
#        age          job  marital  ... euribor3m nr.employed    y
# 41183   73      retired  married  ...     1.028      4963.6  yes
# 41184   46  blue-collar  married  ...     1.028      4963.6   no
# 41185   56      retired  married  ...     1.028      4963.6   no
# 41186   44   technician  married  ...     1.028      4963.6  yes
# 41187   74      retired  married  ...     1.028      4963.6   no
#
# [5 rows x 21 columns]

# %%
#Checking the number of rows and columns
#There are 14,770 rows and 21 columns
bank.shape
# Out:
# (41188, 21)

# %%
#We will check the core statistics for all the columns
bank.describe()
# Out:
#                age      duration  ...     euribor3m   nr.employed
# count  41188.00000  41188.000000  ...  41188.000000  41188.000000
# mean      40.02406    258.285010  ...      3.621291   5167.035911
# std       10.42125    259.279249  ...      1.734447     72.251528
# min       17.00000      0.000000  ...      0.634000   4963.600000
# 25%       32.00000    102.000000  ...      1.344000   5099.100000
# 50%       38.00000    180.000000  ...      4.857000   5191.000000
# 75%       47.00000    319.000000  ...      4.961000   5228.100000
# max       98.00000   4918.000000  ...      5.045000   5228.100000
#
# [8 rows x 10 columns]

# %%
#Describing all columns of the dataframe regardless of data type.
bank.describe(include="all")
# Out:
#                 age     job  marital  ...     euribor3m   nr.employed      y
# count   41188.00000   41188    41188  ...  41188.000000  41188.000000  41188
# unique          NaN      12        4  ...           NaN           NaN      2
# top             NaN  admin.  married  ...           NaN           NaN     no
# freq            NaN   10422    24928  ...           NaN           NaN  36548
# mean       40.02406     NaN      NaN  ...      3.621291   5167.035911    NaN
# std        10.42125     NaN      NaN  ...      1.734447     72.251528    NaN
# min        17.00000     NaN      NaN  ...      0.634000   4963.600000    NaN
# 25%        32.00000     NaN      NaN  ...      1.344000   5099.100000    NaN
# 50%        38.00000     NaN      NaN  ...      4.857000   5191.000000    NaN
# 75%        47.00000     NaN      NaN  ...      4.961000   5228.100000    NaN
# max        98.00000     NaN      NaN  ...      5.045000   5228.100000    NaN
#
# [11 rows x 21 columns]

# %% [markdown]
# ##Data Cleaning

# %% [markdown]
# Here we will check for accuracy, completeness, consistency and uniformity of the data.

# %%
#Checking if the data types are appropriate
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
#Checking the column names for easier reference
bank.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
#Checking for duplicates
bank.duplicated().sum()
# Out:
# 12

# %%
#Checking for null values
bank.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
#We will now drop the irrelevant columns that we will not use for our study and analysis
bank = bank.drop(['campaign', 'pdays','previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
       'cons.conf.idx', 'euribor3m', 'nr.employed'], axis=1)
bank.head()
# Out:
#    age        job  marital    education  ... month day_of_week duration   y
# 0   56  housemaid  married     basic.4y  ...   may         mon      261  no
# 1   57   services  married  high.school  ...   may         mon      149  no
# 2   37   services  married  high.school  ...   may         mon      226  no
# 3   40     admin.  married     basic.6y  ...   may         mon      151  no
# 4   56   services  married  high.school  ...   may         mon      307  no
#
# [5 rows x 12 columns]

# %%
#Now checking for null values, we see there are no null values
bank.isnull().sum()
# Out:
# age            0
# job            0
# marital        0
# education      0
# default        0
# housing        0
# loan           0
# contact        0
# month          0
# day_of_week    0
# duration       0
# y              0
# dtype: int64

# %%
#We'll keep the duplicated values for accurate results
bank.duplicated().sum()
# Out:
# 28

# %%
#Here we'll rename the y column to term deposit representing the prensence/ownership of a term deposit investment
bank.rename(columns={'y': 'term_deposit'}, inplace=True)
bank.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'term_deposit'],
#       dtype='object')

# %% [markdown]
# **Checking for outliers**

# %%
#checking for outliers
col_names = ['age','duration']

fig, ax = plt.subplots(len(col_names), figsize= (8,40))

for i, col_val in enumerate(col_names):
  sns.boxplot(y = bank[col_val], ax= ax[i])
  ax[i].set_title('Box plot - {}'.format(col_val), fontsize= 10)
  ax[i].set_xlabel(col_val, fontsize= 8)
plt.show()

# %% [markdown]
# From the above the outliers are too many to remove as this will affect the accuarcy of the data analysis and the result will be inconclusive.
